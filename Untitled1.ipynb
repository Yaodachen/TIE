# %%
import matplotlib.pyplot as plt
import matplotlib.image as mp
import scipy.io as sio
img = mp.imread('1.jpeg')
print(img)
height = img.shape[0]
width = img.shape[1]
plt.figure(figsize=(width/72,height/72))
ax = plt.subplot(111)
ax.set_xlim(0,width)
ax.set_ylim(height,0)
ax.axis('off')

print(type(img))

# plt.gca().xaxis.set_major_locator(plt.NullLocator())
# plt.gca().yaxis.set_major_locator(plt.NullLocator())
plt.subplots_adjust(top=1,bottom=0,left=0,right=1,hspace =0, wspace =0)
plt.margins(0,0)

plt.imshow(img)
plt.savefig('2.png')
# Out:
# [[[173 174 166]
#   [176 177 169]
#   [178 179 171]
#   ...
#   [116 121 125]
#   [110 115 119]
#   [ 88  93  97]]
#
#  [[174 175 167]
#   [175 176 168]
#   [176 177 169]
#   ...
#   [ 79  87  90]
#   [111 119 122]
#   [115 120 124]]
#
#  [[176 177 169]
#   [174 175 167]
#   [173 174 166]
#   ...
#   [ 82  90  92]
#   [138 146 148]
#   [198 206 208]]
#
#  ...
#
#  [[231 214 196]
#   [230 213 195]
#   [229 212 194]
#   ...
#   [226 216 204]
#   [226 216 204]
#   [225 215 203]]
#
#  [[233 216 198]
#   [231 214 196]
#   [229 212 194]
#   ...
#   [226 216 204]
#   [226 216 204]
#   [225 215 203]]
#
#  [[234 217 199]
#   [231 214 196]
#   [229 212 194]
#   ...
#   [226 216 204]
#   [226 216 204]
#   [202 192 180]]]
# <class 'numpy.ndarray'>

# %%
print(img.shape[1])
# Out:
# 825

# %%
import scipy.io as sio
load_fn = 'saveddata.mat'
image22 = sio.loadmat(load_fn)
image2 = image22['image2']

# %%
import scipy.io as sio
load_fn = 'saveddata.mat'
image22 = sio.loadmat(load_fn)
image2 = image22['image2']

import matplotlib.pyplot as plt
import matplotlib.image as mp
import scipy.io as sio
img = image2
print(img)
height = img.shape[0]
width = img.shape[1]
plt.figure(figsize=(width/72,height/72))
ax = plt.subplot(111)
ax.set_xlim(0,width)
ax.set_ylim(height,0)
ax.axis('off')

print(type(img))

# plt.gca().xaxis.set_major_locator(plt.NullLocator())
# plt.gca().yaxis.set_major_locator(plt.NullLocator())
plt.subplots_adjust(top=1,bottom=0,left=0,right=1,hspace =0, wspace =0)
plt.margins(0,0)

plt.imshow(img)
plt.savefig('2.png')
# Out:
# [[[189 178 146]
#   [199 187 147]
#   [173 160 115]
#   ...
#   [ 18  15   0]
#   [ 24  21   6]
#   [ 27  24   9]]
#
#  [[210 198 160]
#   [196 183 141]
#   [182 169 124]
#   ...
#   [ 20  17   2]
#   [ 27  24   9]
#   [ 37  34  19]]
#
#  [[180 163 119]
#   [177 162 119]
#   [166 151 108]
#   ...
#   [ 37  34  19]
#   [ 36  33  18]
#   [ 30  27  12]]
#
#  ...
#
#  [[ 93  75  35]
#   [ 91  74  31]
#   [ 92  75  32]
#   ...
#   [157 125  38]
#   [125  93  18]
#   [113  82  17]]
#
#  [[ 98  81  38]
#   [ 92  75  32]
#   [ 97  80  36]
#   ...
#   [138 107  25]
#   [112  81  14]
#   [105  75  15]]
#
#  [[ 97  80  37]
#   [ 96  79  35]
#   [ 89  72  28]
#   ...
#   [114  83  18]
#   [116  85  31]
#   [105  72  27]]]
# <class 'numpy.ndarray'>
